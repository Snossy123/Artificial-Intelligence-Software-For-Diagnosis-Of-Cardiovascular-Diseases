# %% [markdown]
# # import¶

# %%
# include working dir
# !conda install -y gdown
# !gdown --id 1UNsbV5xiYDq7vXnArOfAUDXIny08H_yi
# !gdown --id 1VCbWE-DyVYZdDViH75ts62lrkr3rBe_V
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 22.9.0
#   latest version: 23.3.1
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# # All requested packages already installed.
#
# Retrieving notices: ...working... done
# /opt/conda/lib/python3.7/site-packages/gdown/cli.py:130: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   category=FutureWarning,
# Downloading...
# From (uriginal): https://drive.google.com/uc?id=1UNsbV5xiYDq7vXnArOfAUDXIny08H_yi
# From (redirected): https://drive.google.com/uc?id=1UNsbV5xiYDq7vXnArOfAUDXIny08H_yi&confirm=t&uuid=b72046ba-2c40-41fe-a727-d903c3fe0a90
# To: /kaggle/working/dataset_I_Train.zip
# 100%|█████████████████████████████████████████| 534M/534M [00:02<00:00, 231MB/s]
# /opt/conda/lib/python3.7/site-packages/gdown/cli.py:130: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   category=FutureWarning,
# Downloading...
# From (uriginal): https://drive.google.com/uc?id=1VCbWE-DyVYZdDViH75ts62lrkr3rBe_V
# From (redirected): https://drive.google.com/uc?id=1VCbWE-DyVYZdDViH75ts62lrkr3rBe_V&confirm=t&uuid=2317fbb2-b318-4239-ab19-557b6df37fc6
# To: /kaggle/working/dataset_I_Test.zip
# 100%|█████████████████████████████████████████| 435M/435M [00:02<00:00, 203MB/s]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.metrics import accuracy_score
from keras.models import load_model
from keras.initializers import glorot_uniform
from keras.models import Model
from keras.layers import (Input, Conv1D, BatchNormalization, MaxPooling1D, 
                          AveragePooling1D, Flatten, Dense,Add, Activation, 
                          ZeroPadding1D, GlobalMaxPooling1D,MaxPool1D)
from keras.layers import Reshape, Permute, Concatenate, Dropout 
from tensorflow.keras.layers import LayerNormalization, MultiHeadAttention
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import (ModelCheckpoint, TensorBoard, ReduceLROnPlateau,CSVLogger, EarlyStopping)
from sklearn.model_selection import KFold 
import tensorflow as tf
from tensorflow import keras

# %%
# fix random seed for reproducibility
seed = 42
np.random.seed(seed)

# %% [markdown]
# ## load dataset

# %%
def train_test_split():
    # load dataset
    train_seq = pd.read_csv('/kaggle/working/dataset_I_Train.zip')
    test_seq = pd.read_csv('/kaggle/working/dataset_I_Test.zip')
    # split into input (X) and output (Y) variables
    X_train = train_seq.iloc[:,:-1]
    Y_train = train_seq[['output']]
    # encode class values as integers
    encoded_Y_train = pd.get_dummies(Y_train, ['output'])
    # Convert all columns to floats
    encoded_Y_train = encoded_Y_train.astype(float)
    X_test = test_seq.iloc[:,:-1]
    Y_test = test_seq[['output']] 
    encoded_Y_test = pd.get_dummies(Y_test, ['output'])
    # Convert all columns to floats
    encoded_Y_test = encoded_Y_test.astype(float)
    return X_train, encoded_Y_train, X_test, encoded_Y_test

# %%
# load dataset
X_train, y_train, X_test, y_test = train_test_split()

# %% [markdown]
# # Baseline Model

# %% [markdown]
# ## CR-Former model Architectuer

# %%
def positional_encoding(seq_len, embedding_dim):
    pos = np.arange(seq_len)[:, np.newaxis]
    i = np.arange(embedding_dim)[np.newaxis, :]
    angle_rates = 1 / np.power(10000, (2 * (i // 2)) / np.float32(embedding_dim))
    angle_rads = pos * angle_rates

    # apply sin to even indices in the array; 2i
    angle_rads[:, 0::2] = np.sin(angle_rads[:, 0::2])

    # apply cos to odd indices in the array; 2i+1
    angle_rads[:, 1::2] = np.cos(angle_rads[:, 1::2])

    pos_encoding = angle_rads[np.newaxis, ...]

    return tf.cast(pos_encoding, dtype=tf.float32)

def transformer_encoder(inputs, num_heads, ff_dim, dropout_rate=0.1):
    # Input embedding layer
    input_layer = inputs
    x = input_layer
    
    # Positional Encoding
    seq_len = x.shape[1]
    embedding_dim = x.shape[2]
    pos_encoding = positional_encoding(seq_len, embedding_dim)
    x += pos_encoding[:, :seq_len, :]
    
    # Multi-Head Attention
    x = LayerNormalization()(x)
    attn_output = MultiHeadAttention(num_heads=num_heads, key_dim=embedding_dim)(x, x)
    attn_output = Dropout(dropout_rate)(attn_output)
    x = Add()([x, attn_output])
    
    # Feed Forward
    x = LayerNormalization()(x)
    ff_output = Dense(ff_dim, activation='relu')(x)
    ff_output = Dropout(dropout_rate)(ff_output)
    ff_output = Dense(embedding_dim)(ff_output)
    ff_output = Dropout(dropout_rate)(ff_output)
    x = Add()([x, ff_output])
    
    return x

# %%
def identity_block(X, filters, stage, block):
    conv_name_base = f"res{stage}{block}_branch"
    F1, F2 = filters
    X_shortcut = X
    X = Conv1D(F1, 1, strides=1, padding='valid', name=conv_name_base + '2a', kernel_initializer=glorot_uniform(seed=0))(X)
    X = Conv1D(F2, 1, strides=1, padding='valid', name=conv_name_base + '2b', kernel_initializer=glorot_uniform(seed=0))(X)
    X = Add()([X, X_shortcut])
    return X

def convolutional_block(X, filters, stage, block, s=1):
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'
    F1, F2 = filters
    X_shortcut = X
    X = Conv1D(filters=F1, kernel_size=1, strides=s, padding='valid', name=conv_name_base + '2a', kernel_initializer=glorot_uniform(seed=0))(X)
    X = Conv1D(filters=F2, kernel_size=1, strides=1, padding='valid', name=conv_name_base + '2b', kernel_initializer=glorot_uniform(seed=0))(X)
    X_shortcut = Conv1D(filters=F2, kernel_size=1, strides=s, padding='valid', name=conv_name_base + '1', kernel_initializer=glorot_uniform(seed=0))(X_shortcut)
    X = Add()([X, X_shortcut])
    return X

def ResNet_Block(X, f_size, f_num, convblock, i1block, i2block):
    # stage 1-7
    for stage in range(1, 8):
        if stage%2==0:
            X = convolutional_block(X, filters=[f_num, f_num], stage=stage, block=convblock)
        else:
            X = convolutional_block(X, filters=[f_num, f_num], stage=stage, block=convblock)
            X = identity_block(X, [f_num, f_num], stage=stage, block=i1block)
            X = identity_block(X, [f_num, f_num], stage=stage, block=i2block)
    return X

def transformer_encoder(inputs, num_heads, ff_dim, dropout_rate=0.1):
    x = LayerNormalization()(inputs)
    x = MultiHeadAttention(num_heads=num_heads, key_dim=ff_dim)(x, x)
    x = Dropout(dropout_rate)(x)
    x = Add()([inputs, x])
    x = LayerNormalization()(x)
    x = Dense(ff_dim, activation='relu')(x)
    x = Dropout(dropout_rate)(x)
    x = Dense(inputs.shape[-1])(x)
    x = Dropout(dropout_rate)(x)
    x = Add()([inputs, x])
    return x

def build_model(input_shape): 
    input_layer = Input(shape=input_shape)
    
    # Layer 1: Conv1D
    layer = Conv1D(filters=4, kernel_size=16, strides=1, padding='valid', kernel_initializer=glorot_uniform(seed=0))(input_layer)
    layer = BatchNormalization()(layer)

    # Layer 2: MaxPooling1D
    layer = MaxPooling1D(pool_size=2, strides=2)(layer)

    # Layer 3: Conv1D
    layer = Conv1D(filters=6, kernel_size=8, strides=1, padding='valid', kernel_initializer=glorot_uniform(seed=0))(layer)
    layer = BatchNormalization()(layer)

    # Layer 4: MaxPooling1D
    layer = MaxPooling1D(pool_size=2, strides=2)(layer)
    
    # For Skip Connection
    X_shortcut = layer
    
    # Layer 5: ResNet1
    layer = ResNet_Block(layer, 8, 8,'a','b','c')

    # Layer 6: ResNet2
    layer = ResNet_Block(layer, 16, 10,'d','e','f')
    
    # Reshaping And Padding For Additon And Skip Connection
    X_shortcut=Reshape([6,242])(X_shortcut)
    pad = ZeroPadding1D(padding=((4,0)))(X_shortcut)
    X_shortcut=Reshape([242,10])(pad)
    layer = Add()([layer, X_shortcut])

    # Layer 7: MaxPooling1D
    layer = MaxPooling1D(pool_size=2, strides=2)(layer)
    
    # For Skip Connection
    X_shortcut = layer

    # Layer 8: ResNet3
    layer = ResNet_Block(layer,16,12,'g','h','i') 

    # Reshaping And Padding For Additon And Skip Connection
    X_shortcut=Reshape([10,121])(X_shortcut)
    pad = ZeroPadding1D(padding=((2,0)))(X_shortcut)
    X_shortcut=Reshape([121,12])(pad)
    layer = Add()([layer, X_shortcut])

    # Layer 9: MaxPooling1D
    layer = MaxPooling1D(pool_size=2, strides=2)(layer)

    # For Skip Connection
    X_shortcut = layer

    # Layer 10: ResNet4
    layer = ResNet_Block(layer,4,14 ,'j','k','n')
    layer = MaxPooling1D(pool_size = 2, strides=2)(layer)   
    X_shortcut=Reshape([12,60])(X_shortcut)
    pad = ZeroPadding1D(padding=((2,0)))(X_shortcut)
    X_shortcut=Reshape([60,14])(pad)
    X_shortcut = MaxPooling1D(pool_size = 2, strides=2)(X_shortcut)
    layer = Add()([layer, X_shortcut])

    # Layer 11: AveragePooling1D
    layer = AveragePooling1D(pool_size=2, strides=1, padding='same')(layer)

    # Layer 12: Reshape
    #layer = Reshape((420,))(layer)

    # Layer 13-15: Transformer encoding
    num_heads = 5
    feed_forward_dim = 248
    for _ in range(3):
        layer = transformer_encoder(layer, num_heads, feed_forward_dim)
 
    # Layer 16: Fully connected
    layer = Flatten()(layer)
    layer = Dense(units=248, activation='relu')(layer)

    # Layer 17: Softmax
    output_layer = Dense(units=4, activation='softmax')(layer)

    model = Model(inputs=input_layer, outputs=output_layer, name='CRFormer')
    return model

# %% [markdown]
# ## Train Model & Set parameter

# %%
# Optimization settings
num_samples = X_train.shape[1]
num_features = 1
lr = 2 * 10**-5
batch_size = 50
num_epochs = 100
opt = Adam(lr)

# define a callback functions
def getCallbacks():
    checkpoint = ModelCheckpoint(
        filepath='/kaggle/working/model.h5', # file path for saving the model
        monitor='val_loss', # quantity to monitor
        save_best_only=True, # save only the best model (based on the monitor quantity)
        save_weights_only=False, # save the entire model (not just the weights)
        mode='auto', # auto: the mode is inferred from the monitor quantity
        verbose=1 # print messages about the saving process
    )
    early_stopping = EarlyStopping(
        monitor='val_loss', # quantity to monitor
        patience=20, # number of epochs with no improvement before stopping
        verbose=1 # print messages about the early stopping process
    )
    reduce_lr = ReduceLROnPlateau(
        monitor='val_loss', # quantity to monitor
        factor=0.2, # factor by which the learning rate will be reduced. new_lr = lr * factor
        patience=5, # number of epochs with no improvement before reducing learning rate
        verbose=1, # print messages about the learning rate reduction
        min_lr=1e-7 # lower bound on the learning rate
    )
    log_file_name = "/kaggle/working/log_fold_.csv"
    csv_logger = CSVLogger(log_file_name, separator=',', append=False)
    tensorboard = TensorBoard(
        log_dir='/kaggle/working/logs', # directory for storing the logs
        histogram_freq=1, # how often to compute activation and weight histograms (in epochs)
        write_graph=True, # whether to write the graph to TensorBoard
        write_images=True # whether to write image summaries to TensorBoard
    )
    return [checkpoint, early_stopping, csv_logger, reduce_lr, tensorboard]

model = build_model(input_shape=(num_samples, num_features))
model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])

# %%
callbacks = getCallbacks()

# Fit the model on the training data
model.fit(X_train, y_train, epochs=num_epochs, batch_size=batch_size,
callbacks=callbacks, validation_data=(X_test, y_test))
# Out:
# Epoch 1/100
#
100
# 1450/1450 [==============================] - ETA: 0s - loss: 0.0240 - accuracy: 0.9933
# Epoch 47: val_loss did not improve from 0.87785
# 1450/1450 [==============================] - 117s 80ms/step - loss: 0.0240 - accuracy: 0.9933 - val_loss: 1.2352 - val_accuracy: 0.8318 - lr: 4.0000e-06
# Epoch 48/100
# 1450/1450 [==============================] - ETA: 0s - loss: 0.0231 - accuracy: 0.9931
# Epoch 48: val_loss did not improve from 0.87785
# 1450/1450 [==============================] - 117s 81ms/step - loss: 0.0231 - accuracy: 0.9931 - val_loss: 1.1180 - val_accuracy: 0.8317 - lr: 4.0000e-06
# Epoch 49/100
# 1450/1450 [==============================] - ETA: 0s - loss: 0.0204 - accuracy: 0.9944
# Epoch 49: val_loss did not improve from 0.87785
#
# Epoch 49: ReduceLROnPlateau reducing learning rate to 7.999999979801942e-07.
# 1450/1450 [==============================] - 115s 79ms/step - loss: 0.0204 - accuracy: 0.9944 - val_loss: 1.2183 - val_accuracy: 0.8335 - lr: 4.0000e-06
# Epoch 50/100
# 1450/1450 [==============================] - ETA: 0s - loss: 0.0176 - accuracy: 0.9948
# Epoch 50: val_loss did not improve from 0.87785
# 1450/1450 [==============================] - 115s 79ms/step - loss: 0.0176 - accuracy: 0.9948 - val_loss: 1.0642 - val_accuracy: 0.8377 - lr: 8.0000e-07
# Epoch 51/100
# 1450/1450 [==============================] - ETA: 0s - loss: 0.0171 - accuracy: 0.9952
# Epoch 51: val_loss did not improve from 0.87785
# 1450/1450 [==============================] - 113s 78ms/step - loss: 0.0171 - accuracy: 0.9952 - val_loss: 1.1602 - val_accuracy: 0.8345 - lr: 8.0000e-07
# Epoch 52/100
# 1450/1450 [==============================] - ETA: 0s - loss: 0.0178 - accuracy: 0.9953
# Epoch 52: val_loss did not improve from 0.87785
# 1450/1450 [==============================] - 115s 79ms/step - loss: 0.0178 - accuracy: 0.9953 - val_loss: 1.1555 - val_accuracy: 0.8345 - lr: 8.0000e-07
# Epoch 53/100
# 1450/1450 [==============================] - ETA: 0s - loss: 0.0191 - accuracy: 0.9947
# Epoch 53: val_loss did not improve from 0.87785
# 1450/1450 [==============================] - 112s 78ms/step - loss: 0.0191 - accuracy: 0.9947 - val_loss: 1.1392 - val_accuracy: 0.8372 - lr: 8.0000e-07
# Epoch 54/100
# 1450/1450 [==============================] - ETA: 0s - loss: 0.0175 - accuracy: 0.9955
# Epoch 54: val_loss did not improve from 0.87785
#
# Epoch 54: ReduceLROnPlateau reducing learning rate to 1.600000018697756e-07.
# 1450/1450 [==============================] - 117s 81ms/step - loss: 0.0175 - accuracy: 0.9955 - val_loss: 1.1703 - val_accuracy: 0.8341 - lr: 8.0000e-07
# Epoch 55/100
# 1450/1450 [==============================] - ETA: 0s - loss: 0.0179 - accuracy: 0.9945
# Epoch 55: val_loss did not improve from 0.87785
# 1450/1450 [==============================] - 111s 77ms/step - loss: 0.0179 - accuracy: 0.9945 - val_loss: 1.1841 - val_accuracy: 0.8335 - lr: 1.6000e-07
# Epoch 56/100
# 1450/1450 [==============================] - ETA: 0s - loss: 0.0155 - accuracy: 0.9955
# Epoch 56: val_loss did not improve from 0.87785
# 1450/1450 [==============================] - 110s 76ms/step - loss: 0.0155 - accuracy: 0.9955 - val_loss: 1.1587 - val_accuracy: 0.8346 - lr: 1.6000e-07
# Epoch 57/100
# 1450/1450 [==============================] - ETA: 0s - loss: 0.0162 - accuracy: 0.9956
# Epoch 57: val_loss did not improve from 0.87785
# 1450/1450 [==============================] - 111s 77ms/step - loss: 0.0162 - accuracy: 0.9956 - val_loss: 1.1858 - val_accuracy: 0.8338 - lr: 1.6000e-07
# Epoch 58/100
# 1450/1450 [==============================] - ETA: 0s - loss: 0.0157 - accuracy: 0.9954
# Epoch 58: val_loss did not improve from 0.87785
# 1450/1450 [==============================] - 115s 80ms/step - loss: 0.0157 - accuracy: 0.9954 - val_loss: 1.1818 - val_accuracy: 0.8350 - lr: 1.6000e-07
# Epoch 59/100
# 1450/1450 [==============================] - ETA: 0s - loss: 0.0169 - accuracy: 0.9950
# Epoch 59: val_loss did not improve from 0.87785
#
# Epoch 59: ReduceLROnPlateau reducing learning rate to 1e-07.
# 1450/1450 [==============================] - 115s 79ms/step - loss: 0.0169 - accuracy: 0.9950 - val_loss: 1.1685 - val_accuracy: 0.8345 - lr: 1.6000e-07
# Epoch 59: early stopping

# %% [markdown]
# ## Visualize Model Training History

# %%
best_model = load_model('/kaggle/working/model.h5')
print(best_model.summary())
# Out:
# Model: "CRFormer"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_5 (InputLayer)           [(None, 1000, 1)]    0           []
#
#  conv1d_8 (Conv1D)              (None, 985, 4)       68          ['input_5[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 985, 4)      16          ['conv1d_8[0][0]']
#  rmalization)
#
#  max_pooling1d_24 (MaxPooling1D  (None, 492, 4)      0           ['batch_normalization_8[0][0]']
#  )
#
#  conv1d_9 (Conv1D)              (None, 485, 6)       198         ['max_pooling1d_24[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 485, 6)      24          ['conv1d_9[0][0]']
#  rmalization)
#
#  max_pooling1d_25 (MaxPooling1D  (None, 242, 6)      0           ['batch_normalization_9[0][0]']
#  )
#
#  res1a_branch2a (Conv1D)        (None, 242, 8)       56          ['max_pooling1d_25[0][0]']
#
#  res1a_branch2b (Conv1D)        (None, 242, 8)       72          ['res1a_branch2a[0][0]']
#
#  res1a_branch1 (Conv1D)         (None, 242, 8)       56          ['max_pooling1d_25[0][0]']
#
#  add_276 (Add)                  (None, 242, 8)       0           ['res1a_branch2b[0][0]',
#                                                                   'res1a_branch1[0][0]']
#
#  res1b_branch2a (Conv1D)        (None, 242, 8)       72          ['add_276[0][0]']
#
#  res1b_branch2b (Conv1D)        (None, 242, 8)       72          ['res1b_branch2a[0][0]']
#
#  add_277 (Add)                  (None, 242, 8)       0           ['res1b_branch2b[0][0]',
#                                                                   'add_276[0][0]']
#
#  res1c_branch2a (Conv1D)        (None, 242, 8)       72          ['add_277[0][0]']
#
#  res1c_branch2b (Conv1D)        (None, 242, 8)       72          ['res1c_branch2a[0][0]']
#
#  add_278 (Add)                  (None, 242, 8)       0           ['res1c_branch2b[0][0]',
#                                                                   'add_277[0][0]']
#
#  res2a_branch2a (Conv1D)        (None, 242, 8)       72          ['add_278[0][0]']
#
#  res2a_branch2b (Conv1D)        (None, 242, 8)       72          ['res2a_branch2a[0][0]']
#
#  res2a_branch1 (Conv1D)         (None, 242, 8)       72          ['add_278[0][0]']
#
#  add_279 (Add)                  (None, 242, 8)       0           ['res2a_branch2b[0][0]',
#                                                                   'res2a_branch1[0][0]']
#
#  res3a_branch2a (Conv1D)        (None, 242, 8)       72          ['add_279[0][0]']
#
#  res3a_branch2b (Conv1D)        (None, 242, 8)       72          ['res3a_branch2a[0][0]']
#
#  res3a_branch1 (Conv1D)         (None, 242, 8)       72          ['add_279[0][0]']
#
#  add_280 (Add)                  (None, 242, 8)       0           ['res3a_branch2b[0][0]',
#                                                                   'res3a_branch1[0][0]']
#
#  res3b_branch2a (Conv1D)        (None, 242, 8)       72          ['add_280[0][0]']
#
#  res3b_branch2b (Conv1D)        (None, 242, 8)       72          ['res3b_branch2a[0][0]']
#
#  add_281 (Add)                  (None, 242, 8)       0           ['res3b_branch2b[0][0]',
#                                                                   'add_280[0][0]']
#
#  res3c_branch2a (Conv1D)        (None, 242, 8)       72          ['add_281[0][0]']
#
#  res3c_branch2b (Conv1D)        (None, 242, 8)       72          ['res3c_branch2a[0][0]']
#
#  add_282 (Add)                  (None, 242, 8)       0           ['res3c_branch2b[0][0]',
#                                                                   'add_281[0][0]']
#
#  res4a_branch2a (Conv1D)        (None, 242, 8)       72          ['add_282[0][0]']
#
#  res4a_branch2b (Conv1D)        (None, 242, 8)       72          ['res4a_branch2a[0][0]']
#
#  res4a_branch1 (Conv1D)         (None, 242, 8)       72          ['add_282[0][0]']
#
#  add_283 (Add)                  (None, 242, 8)       0           ['res4a_branch2b[0][0]',
#                                                                   'res4a_branch1[0][0]']
#
#  res5a_branch2a (Conv1D)        (None, 242, 8)       72          ['add_283[0][0]']
#
#  res5a_branch2b (Conv1D)        (None, 242, 8)       72          ['res5a_branch2a[0][0]']
#
#  res5a_branch1 (Conv1D)         (None, 242, 8)       72          ['add_283[0][0]']
#
#  add_284 (Add)                  (None, 242, 8)       0           ['res5a_branch2b[0][0]',
#                                                                   'res5a_branch1[0][0]']
#
#  res5b_branch2a (Conv1D)        (None, 242, 8)       72          ['add_284[0][0]']
#
#  res5b_branch2b (Conv1D)        (None, 242, 8)       72          ['res5b_branch2a[0][0]']
#
#  add_285 (Add)                  (None, 242, 8)       0           ['res5b_branch2b[0][0]',
#                                                                   'add_284[0][0]']
#
#  res5c_branch2a (Conv1D)        (None, 242, 8)       72          ['add_285[0][0]']
#
#  res5c_branch2b (Conv1D)        (None, 242, 8)       72          ['res5c_branch2a[0][0]']
#
#  add_286 (Add)                  (None, 242, 8)       0           ['res5c_branch2b[0][0]',
#                                                                   'add_285[0][0]']
#
#  res6a_branch2a (Conv1D)        (None, 242, 8)       72          ['add_286[0][0]']
#
#  res6a_branch2b (Conv1D)        (None, 242, 8)       72          ['res6a_branch2a[0][0]']
#
#  res6a_branch1 (Conv1D)         (None, 242, 8)       72          ['add_286[0][0]']
#
#  add_287 (Add)                  (None, 242, 8)       0           ['res6a_branch2b[0][0]',
#                                                                   'res6a_branch1[0][0]']
#
#  res7a_branch2a (Conv1D)        (None, 242, 8)       72          ['add_287[0][0]']
#
#  res7a_branch2b (Conv1D)        (None, 242, 8)       72          ['res7a_branch2a[0][0]']
#
#  res7a_branch1 (Conv1D)         (None, 242, 8)       72          ['add_287[0][0]']
#
#  add_288 (Add)                  (None, 242, 8)       0           ['res7a_branch2b[0][0]',
#                                                                   'res7a_branch1[0][0]']
#
#  res7b_branch2a (Conv1D)        (None, 242, 8)       72          ['add_288[0][0]']
#
#  res7b_branch2b (Conv1D)        (None, 242, 8)       72          ['res7b_branch2a[0][0]']
#
#  add_289 (Add)                  (None, 242, 8)       0           ['res7b_branch2b[0][0]',
#                                                                   'add_288[0][0]']
#
#  res7c_branch2a (Conv1D)        (None, 242, 8)       72          ['add_289[0][0]']
#
#  res7c_branch2b (Conv1D)        (None, 242, 8)       72          ['res7c_branch2a[0][0]']
#
#  add_290 (Add)                  (None, 242, 8)       0           ['res7c_branch2b[0][0]',
#                                                                   'add_289[0][0]']
#
#  res1d_branch2a (Conv1D)        (None, 242, 10)      90          ['add_290[0][0]']
#
#  res1d_branch2b (Conv1D)        (None, 242, 10)      110         ['res1d_branch2a[0][0]']
#
#  res1d_branch1 (Conv1D)         (None, 242, 10)      90          ['add_290[0][0]']
#
#  add_291 (Add)                  (None, 242, 10)      0           ['res1d_branch2b[0][0]',
#                                                                   'res1d_branch1[0][0]']
#
#  res1e_branch2a (Conv1D)        (None, 242, 10)      110         ['add_291[0][0]']
#
#  res1e_branch2b (Conv1D)        (None, 242, 10)      110         ['res1e_branch2a[0][0]']
#
#  add_292 (Add)                  (None, 242, 10)      0           ['res1e_branch2b[0][0]',
#                                                                   'add_291[0][0]']
#
#  res1f_branch2a (Conv1D)        (None, 242, 10)      110         ['add_292[0][0]']
#
#  res1f_branch2b (Conv1D)        (None, 242, 10)      110         ['res1f_branch2a[0][0]']
#
#  add_293 (Add)                  (None, 242, 10)      0           ['res1f_branch2b[0][0]',
#                                                                   'add_292[0][0]']
#
#  res2d_branch2a (Conv1D)        (None, 242, 10)      110         ['add_293[0][0]']
#
#  res2d_branch2b (Conv1D)        (None, 242, 10)      110         ['res2d_branch2a[0][0]']
#
#  res2d_branch1 (Conv1D)         (None, 242, 10)      110         ['add_293[0][0]']
#
#  add_294 (Add)                  (None, 242, 10)      0           ['res2d_branch2b[0][0]',
#                                                                   'res2d_branch1[0][0]']
#
#  res3d_branch2a (Conv1D)        (None, 242, 10)      110         ['add_294[0][0]']
#
#  res3d_branch2b (Conv1D)        (None, 242, 10)      110         ['res3d_branch2a[0][0]']
#
#  res3d_branch1 (Conv1D)         (None, 242, 10)      110         ['add_294[0][0]']
#
#  add_295 (Add)                  (None, 242, 10)      0           ['res3d_branch2b[0][0]',
#                                                                   'res3d_branch1[0][0]']
#
#  res3e_branch2a (Conv1D)        (None, 242, 10)      110         ['add_295[0][0]']
#
#  res3e_branch2b (Conv1D)        (None, 242, 10)      110         ['res3e_branch2a[0][0]']
#
#  add_296 (Add)                  (None, 242, 10)      0           ['res3e_branch2b[0][0]',
#                                                                   'add_295[0][0]']
#
#  res3f_branch2a (Conv1D)        (None, 242, 10)      110         ['add_296[0][0]']
#
#  res3f_branch2b (Conv1D)        (None, 242, 10)      110         ['res3f_branch2a[0][0]']
#
#  add_297 (Add)                  (None, 242, 10)      0           ['res3f_branch2b[0][0]',
#                                                                   'add_296[0][0]']
#
#  res4d_branch2a (Conv1D)        (None, 242, 10)      110         ['add_297[0][0]']
#
#  res4d_branch2b (Conv1D)        (None, 242, 10)      110         ['res4d_branch2a[0][0]']
#
#  res4d_branch1 (Conv1D)         (None, 242, 10)      110         ['add_297[0][0]']
#
#  add_298 (Add)                  (None, 242, 10)      0           ['res4d_branch2b[0][0]',
#                                                                   'res4d_branch1[0][0]']
#
#  res5d_branch2a (Conv1D)        (None, 242, 10)      110         ['add_298[0][0]']
#
#  res5d_branch2b (Conv1D)        (None, 242, 10)      110         ['res5d_branch2a[0][0]']
#
#  res5d_branch1 (Conv1D)         (None, 242, 10)      110         ['add_298[0][0]']
#
#  add_299 (Add)                  (None, 242, 10)      0           ['res5d_branch2b[0][0]',
#                                                                   'res5d_branch1[0][0]']
#
#  res5e_branch2a (Conv1D)        (None, 242, 10)      110         ['add_299[0][0]']
#
#  res5e_branch2b (Conv1D)        (None, 242, 10)      110         ['res5e_branch2a[0][0]']
#
#  add_300 (Add)                  (None, 242, 10)      0           ['res5e_branch2b[0][0]',
#                                                                   'add_299[0][0]']
#
#  res5f_branch2a (Conv1D)        (None, 242, 10)      110         ['add_300[0][0]']
#
#  res5f_branch2b (Conv1D)        (None, 242, 10)      110         ['res5f_branch2a[0][0]']
#
#  add_301 (Add)                  (None, 242, 10)      0           ['res5f_branch2b[0][0]',
#                                                                   'add_300[0][0]']
#
#  res6d_branch2a (Conv1D)        (None, 242, 10)      110         ['add_301[0][0]']
#
#  res6d_branch2b (Conv1D)        (None, 242, 10)      110         ['res6d_branch2a[0][0]']
#
#  res6d_branch1 (Conv1D)         (None, 242, 10)      110         ['add_301[0][0]']
#
#  add_302 (Add)                  (None, 242, 10)      0           ['res6d_branch2b[0][0]',
#                                                                   'res6d_branch1[0][0]']
#
#  res7d_branch2a (Conv1D)        (None, 242, 10)      110         ['add_302[0][0]']
#
#  res7d_branch2b (Conv1D)        (None, 242, 10)      110         ['res7d_branch2a[0][0]']
#
#  res7d_branch1 (Conv1D)         (None, 242, 10)      110         ['add_302[0][0]']
#
#  add_303 (Add)                  (None, 242, 10)      0           ['res7d_branch2b[0][0]',
#                                                                   'res7d_branch1[0][0]']
#
#  res7e_branch2a (Conv1D)        (None, 242, 10)      110         ['add_303[0][0]']
#
#  res7e_branch2b (Conv1D)        (None, 242, 10)      110         ['res7e_branch2a[0][0]']
#
#  add_304 (Add)                  (None, 242, 10)      0           ['res7e_branch2b[0][0]',
#                                                                   'add_303[0][0]']
#
#  res7f_branch2a (Conv1D)        (None, 242, 10)      110         ['add_304[0][0]']
#
#  reshape_24 (Reshape)           (None, 6, 242)       0           ['max_pooling1d_25[0][0]']
#
#  res7f_branch2b (Conv1D)        (None, 242, 10)      110         ['res7f_branch2a[0][0]']
#
#  zero_padding1d_12 (ZeroPadding  (None, 10, 242)     0           ['reshape_24[0][0]']
#  1D)
#
#  add_305 (Add)                  (None, 242, 10)      0           ['res7f_branch2b[0][0]',
#                                                                   'add_304[0][0]']
#
#  reshape_25 (Reshape)           (None, 242, 10)      0           ['zero_padding1d_12[0][0]']
#
#  add_306 (Add)                  (None, 242, 10)      0           ['add_305[0][0]',
#                                                                   'reshape_25[0][0]']
#
#  max_pooling1d_26 (MaxPooling1D  (None, 121, 10)     0           ['add_306[0][0]']
#  )
#
#  res1g_branch2a (Conv1D)        (None, 121, 12)      132         ['max_pooling1d_26[0][0]']
#
#  res1g_branch2b (Conv1D)        (None, 121, 12)      156         ['res1g_branch2a[0][0]']
#
#  res1g_branch1 (Conv1D)         (None, 121, 12)      132         ['max_pooling1d_26[0][0]']
#
#  add_307 (Add)                  (None, 121, 12)      0           ['res1g_branch2b[0][0]',
#                                                                   'res1g_branch1[0][0]']
#
#  res1h_branch2a (Conv1D)        (None, 121, 12)      156         ['add_307[0][0]']
#
#  res1h_branch2b (Conv1D)        (None, 121, 12)      156         ['res1h_branch2a[0][0]']
#
#  add_308 (Add)                  (None, 121, 12)      0           ['res1h_branch2b[0][0]',
#                                                                   'add_307[0][0]']
#
#  res1i_branch2a (Conv1D)        (None, 121, 12)      156         ['add_308[0][0]']
#
#  res1i_branch2b (Conv1D)        (None, 121, 12)      156         ['res1i_branch2a[0][0]']
#
#  add_309 (Add)                  (None, 121, 12)      0           ['res1i_branch2b[0][0]',
#                                                                   'add_308[0][0]']
#
#  res2g_branch2a (Conv1D)        (None, 121, 12)      156         ['add_309[0][0]']
#
#  res2g_branch2b (Conv1D)        (None, 121, 12)      156         ['res2g_branch2a[0][0]']
#
#  res2g_branch1 (Conv1D)         (None, 121, 12)      156         ['add_309[0][0]']
#
#  add_310 (Add)                  (None, 121, 12)      0           ['res2g_branch2b[0][0]',
#                                                                   'res2g_branch1[0][0]']
#
#  res3g_branch2a (Conv1D)        (None, 121, 12)      156         ['add_310[0][0]']
#
#  res3g_branch2b (Conv1D)        (None, 121, 12)      156         ['res3g_branch2a[0][0]']
#
#  res3g_branch1 (Conv1D)         (None, 121, 12)      156         ['add_310[0][0]']
#
#  add_311 (Add)                  (None, 121, 12)      0           ['res3g_branch2b[0][0]',
#                                                                   'res3g_branch1[0][0]']
#
#  res3h_branch2a (Conv1D)        (None, 121, 12)      156         ['add_311[0][0]']
#
#  res3h_branch2b (Conv1D)        (None, 121, 12)      156         ['res3h_branch2a[0][0]']
#
#  add_312 (Add)                  (None, 121, 12)      0           ['res3h_branch2b[0][0]',
#                                                                   'add_311[0][0]']
#
#  res3i_branch2a (Conv1D)        (None, 121, 12)      156         ['add_312[0][0]']
#
#  res3i_branch2b (Conv1D)        (None, 121, 12)      156         ['res3i_branch2a[0][0]']
#
#  add_313 (Add)                  (None, 121, 12)      0           ['res3i_branch2b[0][0]',
#                                                                   'add_312[0][0]']
#
#  res4g_branch2a (Conv1D)        (None, 121, 12)      156         ['add_313[0][0]']
#
#  res4g_branch2b (Conv1D)        (None, 121, 12)      156         ['res4g_branch2a[0][0]']
#
#  res4g_branch1 (Conv1D)         (None, 121, 12)      156         ['add_313[0][0]']
#
#  add_314 (Add)                  (None, 121, 12)      0           ['res4g_branch2b[0][0]',
#                                                                   'res4g_branch1[0][0]']
#
#  res5g_branch2a (Conv1D)        (None, 121, 12)      156         ['add_314[0][0]']
#
#  res5g_branch2b (Conv1D)        (None, 121, 12)      156         ['res5g_branch2a[0][0]']
#
#  res5g_branch1 (Conv1D)         (None, 121, 12)      156         ['add_314[0][0]']
#
#  add_315 (Add)                  (None, 121, 12)      0           ['res5g_branch2b[0][0]',
#                                                                   'res5g_branch1[0][0]']
#
#  res5h_branch2a (Conv1D)        (None, 121, 12)      156         ['add_315[0][0]']
#
#  res5h_branch2b (Conv1D)        (None, 121, 12)      156         ['res5h_branch2a[0][0]']
#
#  add_316 (Add)                  (None, 121, 12)      0           ['res5h_branch2b[0][0]',
#                                                                   'add_315[0][0]']
#
#  res5i_branch2a (Conv1D)        (None, 121, 12)      156         ['add_316[0][0]']
#
#  res5i_branch2b (Conv1D)        (None, 121, 12)      156         ['res5i_branch2a[0][0]']
#
#  add_317 (Add)                  (None, 121, 12)      0           ['res5i_branch2b[0][0]',
#                                                                   'add_316[0][0]']
#
#  res6g_branch2a (Conv1D)        (None, 121, 12)      156         ['add_317[0][0]']
#
#  res6g_branch2b (Conv1D)        (None, 121, 12)      156         ['res6g_branch2a[0][0]']
#
#  res6g_branch1 (Conv1D)         (None, 121, 12)      156         ['add_317[0][0]']
#
#  add_318 (Add)                  (None, 121, 12)      0           ['res6g_branch2b[0][0]',
#                                                                   'res6g_branch1[0][0]']
#
#  res7g_branch2a (Conv1D)        (None, 121, 12)      156         ['add_318[0][0]']
#
#  res7g_branch2b (Conv1D)        (None, 121, 12)      156         ['res7g_branch2a[0][0]']
#
#  res7g_branch1 (Conv1D)         (None, 121, 12)      156         ['add_318[0][0]']
#
#  add_319 (Add)                  (None, 121, 12)      0           ['res7g_branch2b[0][0]',
#                                                                   'res7g_branch1[0][0]']
#
#  res7h_branch2a (Conv1D)        (None, 121, 12)      156         ['add_319[0][0]']
#
#  res7h_branch2b (Conv1D)        (None, 121, 12)      156         ['res7h_branch2a[0][0]']
#
#  add_320 (Add)                  (None, 121, 12)      0           ['res7h_branch2b[0][0]',
#                                                                   'add_319[0][0]']
#
#  res7i_branch2a (Conv1D)        (None, 121, 12)      156         ['add_320[0][0]']
#
#  reshape_26 (Reshape)           (None, 10, 121)      0           ['max_pooling1d_26[0][0]']
#
#  res7i_branch2b (Conv1D)        (None, 121, 12)      156         ['res7i_branch2a[0][0]']
#
#  zero_padding1d_13 (ZeroPadding  (None, 12, 121)     0           ['reshape_26[0][0]']
#  1D)
#
#  add_321 (Add)                  (None, 121, 12)      0           ['res7i_branch2b[0][0]',
#                                                                   'add_320[0][0]']
#
#  reshape_27 (Reshape)           (None, 121, 12)      0           ['zero_padding1d_13[0][0]']
#
#  add_322 (Add)                  (None, 121, 12)      0           ['add_321[0][0]',
#                                                                   'reshape_27[0][0]']
#
#  max_pooling1d_27 (MaxPooling1D  (None, 60, 12)      0           ['add_322[0][0]']
#  )
#
#  res1j_branch2a (Conv1D)        (None, 60, 14)       182         ['max_pooling1d_27[0][0]']
#
#  res1j_branch2b (Conv1D)        (None, 60, 14)       210         ['res1j_branch2a[0][0]']
#
#  res1j_branch1 (Conv1D)         (None, 60, 14)       182         ['max_pooling1d_27[0][0]']
#
#  add_323 (Add)                  (None, 60, 14)       0           ['res1j_branch2b[0][0]',
#                                                                   'res1j_branch1[0][0]']
#
#  res1k_branch2a (Conv1D)        (None, 60, 14)       210         ['add_323[0][0]']
#
#  res1k_branch2b (Conv1D)        (None, 60, 14)       210         ['res1k_branch2a[0][0]']
#
#  add_324 (Add)                  (None, 60, 14)       0           ['res1k_branch2b[0][0]',
#                                                                   'add_323[0][0]']
#
#  res1n_branch2a (Conv1D)        (None, 60, 14)       210         ['add_324[0][0]']
#
#  res1n_branch2b (Conv1D)        (None, 60, 14)       210         ['res1n_branch2a[0][0]']
#
#  add_325 (Add)                  (None, 60, 14)       0           ['res1n_branch2b[0][0]',
#                                                                   'add_324[0][0]']
#
#  res2j_branch2a (Conv1D)        (None, 60, 14)       210         ['add_325[0][0]']
#
#  res2j_branch2b (Conv1D)        (None, 60, 14)       210         ['res2j_branch2a[0][0]']
#
#  res2j_branch1 (Conv1D)         (None, 60, 14)       210         ['add_325[0][0]']
#
#  add_326 (Add)                  (None, 60, 14)       0           ['res2j_branch2b[0][0]',
#                                                                   'res2j_branch1[0][0]']
#
#  res3j_branch2a (Conv1D)        (None, 60, 14)       210         ['add_326[0][0]']
#
#  res3j_branch2b (Conv1D)        (None, 60, 14)       210         ['res3j_branch2a[0][0]']
#
#  res3j_branch1 (Conv1D)         (None, 60, 14)       210         ['add_326[0][0]']
#
#  add_327 (Add)                  (None, 60, 14)       0           ['res3j_branch2b[0][0]',
#                                                                   'res3j_branch1[0][0]']
#
#  res3k_branch2a (Conv1D)        (None, 60, 14)       210         ['add_327[0][0]']
#
#  res3k_branch2b (Conv1D)        (None, 60, 14)       210         ['res3k_branch2a[0][0]']
#
#  add_328 (Add)                  (None, 60, 14)       0           ['res3k_branch2b[0][0]',
#                                                                   'add_327[0][0]']
#
#  res3n_branch2a (Conv1D)        (None, 60, 14)       210         ['add_328[0][0]']
#
#  res3n_branch2b (Conv1D)        (None, 60, 14)       210         ['res3n_branch2a[0][0]']
#
#  add_329 (Add)                  (None, 60, 14)       0           ['res3n_branch2b[0][0]',
#                                                                   'add_328[0][0]']
#
#  res4j_branch2a (Conv1D)        (None, 60, 14)       210         ['add_329[0][0]']
#
#  res4j_branch2b (Conv1D)        (None, 60, 14)       210         ['res4j_branch2a[0][0]']
#
#  res4j_branch1 (Conv1D)         (None, 60, 14)       210         ['add_329[0][0]']
#
#  add_330 (Add)                  (None, 60, 14)       0           ['res4j_branch2b[0][0]',
#                                                                   'res4j_branch1[0][0]']
#
#  res5j_branch2a (Conv1D)        (None, 60, 14)       210         ['add_330[0][0]']
#
#  res5j_branch2b (Conv1D)        (None, 60, 14)       210         ['res5j_branch2a[0][0]']
#
#  res5j_branch1 (Conv1D)         (None, 60, 14)       210         ['add_330[0][0]']
#
#  add_331 (Add)                  (None, 60, 14)       0           ['res5j_branch2b[0][0]',
#                                                                   'res5j_branch1[0][0]']
#
#  res5k_branch2a (Conv1D)        (None, 60, 14)       210         ['add_331[0][0]']
#
#  res5k_branch2b (Conv1D)        (None, 60, 14)       210         ['res5k_branch2a[0][0]']
#
#  add_332 (Add)                  (None, 60, 14)       0           ['res5k_branch2b[0][0]',
#                                                                   'add_331[0][0]']
#
#  res5n_branch2a (Conv1D)        (None, 60, 14)       210         ['add_332[0][0]']
#
#  res5n_branch2b (Conv1D)        (None, 60, 14)       210         ['res5n_branch2a[0][0]']
#
#  add_333 (Add)                  (None, 60, 14)       0           ['res5n_branch2b[0][0]',
#                                                                   'add_332[0][0]']
#
#  res6j_branch2a (Conv1D)        (None, 60, 14)       210         ['add_333[0][0]']
#
#  res6j_branch2b (Conv1D)        (None, 60, 14)       210         ['res6j_branch2a[0][0]']
#
#  res6j_branch1 (Conv1D)         (None, 60, 14)       210         ['add_333[0][0]']
#
#  add_334 (Add)                  (None, 60, 14)       0           ['res6j_branch2b[0][0]',
#                                                                   'res6j_branch1[0][0]']
#
#  res7j_branch2a (Conv1D)        (None, 60, 14)       210         ['add_334[0][0]']
#
#  res7j_branch2b (Conv1D)        (None, 60, 14)       210         ['res7j_branch2a[0][0]']
#
#  res7j_branch1 (Conv1D)         (None, 60, 14)       210         ['add_334[0][0]']
#
#  add_335 (Add)                  (None, 60, 14)       0           ['res7j_branch2b[0][0]',
#                                                                   'res7j_branch1[0][0]']
#
#  res7k_branch2a (Conv1D)        (None, 60, 14)       210         ['add_335[0][0]']
#
#  res7k_branch2b (Conv1D)        (None, 60, 14)       210         ['res7k_branch2a[0][0]']
#
#  add_336 (Add)                  (None, 60, 14)       0           ['res7k_branch2b[0][0]',
#                                                                   'add_335[0][0]']
#
#  res7n_branch2a (Conv1D)        (None, 60, 14)       210         ['add_336[0][0]']
#
#  reshape_28 (Reshape)           (None, 12, 60)       0           ['max_pooling1d_27[0][0]']
#
#  res7n_branch2b (Conv1D)        (None, 60, 14)       210         ['res7n_branch2a[0][0]']
#
#  zero_padding1d_14 (ZeroPadding  (None, 14, 60)      0           ['reshape_28[0][0]']
#  1D)
#
#  add_337 (Add)                  (None, 60, 14)       0           ['res7n_branch2b[0][0]',
#                                                                   'add_336[0][0]']
#
#  reshape_29 (Reshape)           (None, 60, 14)       0           ['zero_padding1d_14[0][0]']
#
#  max_pooling1d_28 (MaxPooling1D  (None, 30, 14)      0           ['add_337[0][0]']
#  )
#
#  max_pooling1d_29 (MaxPooling1D  (None, 30, 14)      0           ['reshape_29[0][0]']
#  )
#
#  add_338 (Add)                  (None, 30, 14)       0           ['max_pooling1d_28[0][0]',
#                                                                   'max_pooling1d_29[0][0]']
#
#  average_pooling1d_4 (AveragePo  (None, 30, 14)      0           ['add_338[0][0]']
#  oling1D)
#
#  layer_normalization_24 (LayerN  (None, 30, 14)      28          ['average_pooling1d_4[0][0]']
#  ormalization)
#
#  multi_head_attention_12 (Multi  (None, 30, 14)      73174       ['layer_normalization_24[0][0]',
#  HeadAttention)                                                   'layer_normalization_24[0][0]']
#
#  dropout_36 (Dropout)           (None, 30, 14)       0           ['multi_head_attention_12[0][0]']
#
#  add_339 (Add)                  (None, 30, 14)       0           ['average_pooling1d_4[0][0]',
#                                                                   'dropout_36[0][0]']
#
#  layer_normalization_25 (LayerN  (None, 30, 14)      28          ['add_339[0][0]']
#  ormalization)
#
#  dense_32 (Dense)               (None, 30, 248)      3720        ['layer_normalization_25[0][0]']
#
#  dropout_37 (Dropout)           (None, 30, 248)      0           ['dense_32[0][0]']
#
#  dense_33 (Dense)               (None, 30, 14)       3486        ['dropout_37[0][0]']
#
#  dropout_38 (Dropout)           (None, 30, 14)       0           ['dense_33[0][0]']
#
#  add_340 (Add)                  (None, 30, 14)       0           ['average_pooling1d_4[0][0]',
#                                                                   'dropout_38[0][0]']
#
#  layer_normalization_26 (LayerN  (None, 30, 14)      28          ['add_340[0][0]']
#  ormalization)
#
#  multi_head_attention_13 (Multi  (None, 30, 14)      73174       ['layer_normalization_26[0][0]',
#  HeadAttention)                                                   'layer_normalization_26[0][0]']
#
#  dropout_39 (Dropout)           (None, 30, 14)       0           ['multi_head_attention_13[0][0]']
#
#  add_341 (Add)                  (None, 30, 14)       0           ['add_340[0][0]',
#                                                                   'dropout_39[0][0]']
#
#  layer_normalization_27 (LayerN  (None, 30, 14)      28          ['add_341[0][0]']
#  ormalization)
#
#  dense_34 (Dense)               (None, 30, 248)      3720        ['layer_normalization_27[0][0]']
#
#  dropout_40 (Dropout)           (None, 30, 248)      0           ['dense_34[0][0]']
#
#  dense_35 (Dense)               (None, 30, 14)       3486        ['dropout_40[0][0]']
#
#  dropout_41 (Dropout)           (None, 30, 14)       0           ['dense_35[0][0]']
#
#  add_342 (Add)                  (None, 30, 14)       0           ['add_340[0][0]',
#                                                                   'dropout_41[0][0]']
#
#  layer_normalization_28 (LayerN  (None, 30, 14)      28          ['add_342[0][0]']
#  ormalization)
#
#  multi_head_attention_14 (Multi  (None, 30, 14)      73174       ['layer_normalization_28[0][0]',
#  HeadAttention)                                                   'layer_normalization_28[0][0]']
#
#  dropout_42 (Dropout)           (None, 30, 14)       0           ['multi_head_attention_14[0][0]']
#
#  add_343 (Add)                  (None, 30, 14)       0           ['add_342[0][0]',
#                                                                   'dropout_42[0][0]']
#
#  layer_normalization_29 (LayerN  (None, 30, 14)      28          ['add_343[0][0]']
#  ormalization)
#
#  dense_36 (Dense)               (None, 30, 248)      3720        ['layer_normalization_29[0][0]']
#
#  dropout_43 (Dropout)           (None, 30, 248)      0           ['dense_36[0][0]']
#
#  dense_37 (Dense)               (None, 30, 14)       3486        ['dropout_43[0][0]']
#
#  dropout_44 (Dropout)           (None, 30, 14)       0           ['dense_37[0][0]']
#
#  add_344 (Add)                  (None, 30, 14)       0           ['add_342[0][0]',
#                                                                   'dropout_44[0][0]']
#
#  flatten_4 (Flatten)            (None, 420)          0           ['add_344[0][0]']
#
#  dense_38 (Dense)               (None, 248)          104408      ['flatten_4[0][0]']
#
#  dense_39 (Dense)               (None, 4)            996         ['dense_38[0][0]']
#
# ==================================================================================================
# Total params: 367,118
# Trainable params: 367,098
# Non-trainable params: 20
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Save Model without_callbacks

# %%
model.save("my_model_without_callbacks.h5")
# best_model.save("my_model_without_callbacks.tflite")
# tensorflow_graph = tf.saved_model.load("/kaggle/working/my_model_without_callbacks.h5")
# config = model.get_config()  # Retrieve the config
# At loading time, register the custom objects with a `custom_object_scope`:
# custom_objects = {"CustomLayer": CustomLayer, "custom_activation": custom_activation}
# with keras.utils.custom_object_scope(custom_objects):
#     new_model = keras.Model.from_config(config)
# serialize model to JSON
model_json = model.to_json()
with open("ECG_classification_model_interpatient_without_callbacks.json", "w") as json_file:
    json_file.write(model_json)
# Convert the model.
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()

# Save the model.
with open('interpatient_model_without_callbacks.tflite', 'wb') as f:
    f.write(tflite_model)

print('TFLite Model save done!')
# Out:
# TFLite Model save done!

# %% [markdown]
# ## Evaluate Model

# %%
best_model = load_model('/kaggle/working/model.h5')
accuracy_score(y_test, best_model.predict(X_test).round())
# Out:
# 1797/1797 [==============================] - 38s 20ms/step
# 0.8518782608695652

# %% [markdown]
# ## Communication using case study

# %%
# test_model
test_case = pd.read_csv("/kaggle/input/testdata/Book2.csv")
pred = best_model.predict(test_case).round()
out_col = ['output_CAD', 'output_CHF', 'output_MI', 'output_Normal']
output = {out_col[i]:pred[0][i] for i in range(4)}
output_class = max(output, key=output.get).split('_')[-1]
"output_class = " + output_class
# Out:
# 1/1 [==============================] - 0s 87ms/step
# 'output_class = Normal'

# %% [markdown]
# # End Model Training Notebook
